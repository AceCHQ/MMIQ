# %%
from IPython.display import display, Image
from datasets import load_dataset

dataset = load_dataset("huanqia/MM-IQ")

# %%
example = dataset['test'][0]
print("Data_id:", example["data_id"])
print("Question:", example["question"])
print("Answer:", example["answer"])
print("Category:", example["category"])
# Display the image
print("Image context:")
display(example["image"])
# Out:
# Data_id: 0
# Question: Choose the most appropriate option from the four given choices to fill in the question mark, so that it presents a certain regularity:
# Answer: B
# Category: Temporal Movement
# Image context:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=435x486>
